# %% [markdown]
# # Introdução ao Matplotlib
#
# O **Matplotlib** é a biblioteca de visualização de dados mais tradicional e poderosa do Python. Criada por **John D. Hunter**, ela permite criar gráficos 2D e 3D altamente personalizáveis.
#
# ### 🔧 Características:
# - Muito flexível: permite controlar cada elemento do gráfico (cor, eixos, estilo, anotações, etc.).
# - Base para outras bibliotecas (Seaborn, Pandas Plot, etc.).
# - Produz gráficos para relatórios científicos, engenharia, estatística e mais.
#
# No entanto, por ser tão flexível, pode exigir mais código para fazer gráficos simples.

# %% [markdown]
# # Introdução ao Seaborn
#
# O **Seaborn** é uma biblioteca de visualização estatística baseada no Matplotlib. Criada por **Michael Waskom**, ela facilita a criação de gráficos bonitos com menos código, especialmente a partir de `DataFrames`.
#
# ### 🎯 Objetivo principal:
# Permitir gráficos estatísticos padronizados e prontos para análise de dados.
#
# ### 🌟 Vantagens:
# - Integração nativa com `pandas`.
# - Suporte automático a estatísticas (médias, regressões, distribuição).
# - Estilos visuais bonitos por padrão.
# - Ótimo para gráficos rápidos e de alto nível.
#
# Seaborn **não substitui** o Matplotlib, mas o complementa.

# %% [markdown]
# # Matplotlib vs Seaborn
#
# | Aspecto                         | Matplotlib                                     | Seaborn                                           |
# |----------------------------------|------------------------------------------------|----------------------------------------------------|
# | Nível de controle                | Muito alto (baixo nível)                      | Médio (alto nível, com base no matplotlib)         |
# | Integração com pandas            | Manual (com `.plot()`)                        | Automática (`data=`, `x=`, `y=`)                   |
# | Estética dos gráficos padrão     | Simples                                       | Bonita e informativa                              |
# | Criação de gráficos estatísticos | Manual (ex: boxplot exige dados agrupados)   | Automática (ex: `sns.boxplot()`)                  |
# | Facilidade de uso                | Exige mais linhas de código                   | Rápido e conciso                                   |
# | Personalização                   | Total, mas verbosa                            | Menor, mas com estilo moderno                     |
# | Casos de uso                     | Publicações científicas, relatórios técnicos  | Exploração e análise de dados                     |

# %% [markdown]
# # Tipos de Gráficos por Biblioteca
#
# Abaixo estão os principais tipos de gráficos que podem ser criados com cada biblioteca:
#
# | Tipo de Gráfico             | Matplotlib               | Seaborn                     |
# |----------------------------|---------------------------|------------------------------|
# | Linha (Line plot)          | `plt.plot()`              | `sns.lineplot()`            |
# | Barras                     | `plt.bar()`, `barh()`     | `sns.barplot()`, `countplot()` |
# | Histograma                 | `plt.hist()`              | `sns.histplot()`            |
# | Densidade (KDE)            | manual + scipy            | `sns.kdeplot()`             |
# | Dispersão (Scatter)        | `plt.scatter()`           | `sns.scatterplot()`         |
# | Boxplot                    | `plt.boxplot()`           | `sns.boxplot()`             |
# | Violin plot                | ✖️ precisa de código extra | `sns.violinplot()`          |
# | Swarm / Strip              | ✖️                        | `sns.swarmplot()`, `stripplot()` |
# | Torta (Pie chart)          | `plt.pie()`               | ✖️ (não implementado)        |
# | Heatmap                    | `plt.imshow()`            | `sns.heatmap()`             |
# | Regressão                  | manual com `np.polyfit()` | `sns.lmplot()`, `regplot()` |
# | Gráficos em grade (grid)   | `plt.subplots()`          | `sns.pairplot()`, `FacetGrid` |
#
# **Legenda:**
# ✔️ = disponível | ✖️ = não disponível ou não nativo

# %%
# Matplotlib

import matplotlib.pyplot as plt

plt.hist(df['Valor'], bins=10, color='gray')
plt.title("Histograma com Matplotlib")
plt.xlabel("Valor")
plt.ylabel("Frequência")
plt.show()

# %%
# Seaborn

import seaborn as sns
sns.histplot(data=df, x='Valor', bins=10, kde=True)
plt.title("Histograma com Seaborn")
plt.show()

# %% [markdown]
# ## 3. Estilos Globais e Paletas no Seaborn
#
# O Seaborn permite configurar estilos de gráficos globalmente, como:
#
# - `whitegrid`, `darkgrid`, `white`, `dark`, `ticks`
#
# Também podemos definir paletas de cores personalizadas como:
#
# - `pastel`, `deep`, `muted`, `bright`, `dark`, `colorblind`
#
# Essas configurações afetam todos os gráficos seguintes no notebook.

# %%
# Definindo estilo e paleta
sns.set_style("whitegrid")
sns.set_palette("pastel")

# Exemplo: Boxplot estilizado
sns.boxplot(data=df, x='Categoria', y='Valor', hue='Grupo')
plt.title("Boxplot com estilo personalizado")
plt.show()

# %% [markdown]
# ### Matplotlib

# %% [markdown]
# | Tipo de Gráfico         | Função Principal                  |
# | ----------------------- | --------------------------------- |
# | **Linha (Line plot)**   | `plt.plot()`                      |
# | **Barras**              | `plt.bar()`, `plt.barh()`         |
# | **Histograma**          | `plt.hist()`                      |
# | **Dispersão (scatter)** | `plt.scatter()`                   |
# | **Pizza (Pie)**         | `plt.pie()`                       |
# | **Boxplot**             | `plt.boxplot()`                   |
# | **Área**                | `plt.fill_between()`              |
# | **Imagem (heatmap)**    | `plt.imshow()`                    |
# | **Gráficos múltiplos**  | `plt.subplot()`, `plt.subplots()` |

# %% [markdown]
# ### Seaborn

# %% [markdown]
# | Tipo de Gráfico             | Função                             | Ideal para...                              |
# | --------------------------- | ---------------------------------- | ------------------------------------------ |
# | **Histograma**              | `sns.histplot()`                   | Distribuição de uma variável               |
# | **Densidade (KDE)**         | `sns.kdeplot()`                    | Estimativa de densidade                    |
# | **Dispersão (Scatter)**     | `sns.scatterplot()`, `relplot()`   | Correlação entre duas variáveis            |
# | **Linha temporal**          | `sns.lineplot()`                   | Séries temporais                           |
# | **Gráfico de barras**       | `sns.barplot()`                    | Comparações entre categorias (média)       |
# | **Contagem (barras)**       | `sns.countplot()`                  | Frequência de categorias                   |
# | **Boxplot**                 | `sns.boxplot()`                    | Distribuição com quartis                   |
# | **Violin plot**             | `sns.violinplot()`                 | Distribuição e densidade ao mesmo tempo    |
# | **Swarmplot / Stripplot**   | `sns.swarmplot()` / `stripplot()`  | Pontos categóricos                         |
# | **Heatmap (mapa de calor)** | `sns.heatmap()`                    | Tabelas de correlação e frequências        |
# | **Pairplot**                | `sns.pairplot()`                   | Análise multivariada com gráficos em grade |
# | **FacetGrid / catplot**     | `sns.catplot()`, `sns.FacetGrid()` | Múltiplos gráficos segmentados             |
# | **Mapa de regressão**       | `sns.lmplot()` / `sns.regplot()`   | Regressões lineares automáticas            |
#
#
#
# consultar a documentação: https://seaborn.pydata.org/examples/index.html
